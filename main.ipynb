# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from src.data.data_handler import load_and_anylise
from src.models.binary_model import train_and_evaluate
from src.models.multiclass_model import train_multiclass_models
#Загрузить базу данныых из директории и построить графики для анализа данных
df=load_and_anylise("data")

# %%
# Обучение бинарных классификационных моделей и их оценка
train_and_evaluate(df)
# Out:
# Logistic Regression:
#   Accuracy: 0.8406
#   Recall: 0.9909
#   F1 Score: 0.9079
#   AUC: 0.9075
#
# k-Nearest Neighbors:
#   Accuracy: 0.8986
#   Recall: 0.9498
#   F1 Score: 0.9369
#   AUC: 0.9455
#
# Random Forest:
#   Accuracy: 0.9638
#   Recall: 0.9863
#   F1 Score: 0.9774
#   AUC: 0.9927
#
# Support Vector Machine:
#   Accuracy: 0.8587
#   Recall: 0.9680
#   F1 Score: 0.9158
#   AUC: 0.9193
#
# Gradient Boosting:
#   Accuracy: 0.9384
#   Recall: 0.9772
#   F1 Score: 0.9618
#   AUC: 0.9894
#
# Лучшая модель: Random Forest
# c:\Users\Daniel\Desktop\milk-project\src\models\binary_model.py:71: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig1.show()
# c:\Users\Daniel\Desktop\milk-project\src\models\binary_model.py:81: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig2.show()

# %%
# Обучение многоклассовых классификационных моделей и их оценка
train_multiclass_models(df)
# Out:
# Logistic Regression:
#   Accuracy: 0.5036
#   Recall: 0.5036
#   F1 Score: 0.4433
#   AUC: 0.8396
#
# k-Nearest Neighbors:
#   Accuracy: 0.6957
#   Recall: 0.6957
#   F1 Score: 0.6967
#   AUC: 0.9318
#
# Random Forest:
#   Accuracy: 0.8478
#   Recall: 0.8478
#   F1 Score: 0.8465
#   AUC: 0.9815
#
# Support Vector Machine:
#   Accuracy: 0.6196
#   Recall: 0.6196
#   F1 Score: 0.5894
#   AUC: 0.9289
#
# Gradient Boosting:
#   Accuracy: 0.8551
#   Recall: 0.8551
#   F1 Score: 0.8548
#   AUC: 0.9803
#
# Лучшая модель: Random Forest
